# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#Download data
# 2019
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-02.csv > yellow_trips_19_02.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-03.csv > yellow_trips_19_03.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-04.csv > yellow_trips_19_04.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-05.csv > yellow_trips_19_05.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-06.csv > yellow_trips_19_06.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-07.csv > yellow_trips_19_07.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-08.csv > yellow_trips_19_08.csv    
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-09.csv > yellow_trips_19_09.csv  
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-10.csv > yellow_trips_19_10.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-11.csv > yellow_trips_19_11.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-12.csv > yellow_trips_19_12.csv
# 2020
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv > yellow_trips_20_01.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv > yellow_trips_20_02.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-03.csv > yellow_trips_20_03.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-04.csv > yellow_trips_20_04.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-05.csv > yellow_trips_20_05.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv > yellow_trips_20_06.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-07.csv > yellow_trips_20_07.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-08.csv > yellow_trips_20_08.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-09.csv > yellow_trips_20_09.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-10.csv > yellow_trips_20_10.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-11.csv > yellow_trips_20_11.csv
# !curl https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-12.csv > yellow_trips_20_12.csv

# %%
# Create Dataframe
#2019
yt_1901 = pd.read_csv('yellow_trips_19_01.csv', error_bad_lines=False)
yt_1902 = pd.read_csv('yellow_trips_19_02.csv', error_bad_lines=False)
yt_1903 = pd.read_csv('yellow_trips_19_03.csv', error_bad_lines=False)
yt_1904 = pd.read_csv('yellow_trips_19_04.csv', error_bad_lines=False)
yt_1905 = pd.read_csv('yellow_trips_19_05.csv', error_bad_lines=False)
yt_1906 = pd.read_csv('yellow_trips_19_06.csv', error_bad_lines=False)
yt_1907 = pd.read_csv('yellow_trips_19_07.csv', error_bad_lines=False)
yt_1908 = pd.read_csv('yellow_trips_19_08.csv', error_bad_lines=False)
yt_1909 = pd.read_csv('yellow_trips_19_09.csv', error_bad_lines=False)
yt_1910 = pd.read_csv('yellow_trips_19_10.csv', error_bad_lines=False)
yt_1911 = pd.read_csv('yellow_trips_19_11.csv', error_bad_lines=False)
yt_1912 = pd.read_csv('yellow_trips_19_12.csv', error_bad_lines=False)
#2020
yt_2001 = pd.read_csv('yellow_trips_20_01.csv', error_bad_lines=False)
yt_2002 = pd.read_csv('yellow_trips_20_02.csv', error_bad_lines=False)
yt_2003 = pd.read_csv('yellow_trips_20_03.csv', error_bad_lines=False)
yt_2004 = pd.read_csv('yellow_trips_20_04.csv', error_bad_lines=False)
yt_2005 = pd.read_csv('yellow_trips_20_05.csv', error_bad_lines=False)
yt_2006 = pd.read_csv('yellow_trips_20_06.csv', error_bad_lines=False)
yt_2007 = pd.read_csv('yellow_trips_20_07.csv', error_bad_lines=False)
yt_2008 = pd.read_csv('yellow_trips_20_08.csv', error_bad_lines=False)
yt_2009 = pd.read_csv('yellow_trips_20_09.csv', error_bad_lines=False)
yt_2010 = pd.read_csv('yellow_trips_20_10.csv', error_bad_lines=False)
yt_2011 = pd.read_csv('yellow_trips_20_11.csv', error_bad_lines=False)
yt_2012 = pd.read_csv('yellow_trips_20_12.csv', error_bad_lines=False)
# Out:
# C:\Users\Jin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# To datetime, might take some time
# 2019
yt_1901[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1901[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1902[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1902[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1903[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1903[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1904[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1904[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1905[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1905[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1906[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1906[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1907[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1907[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1908[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1908[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1909[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1909[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1910[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1910[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1911[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1911[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_1912[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_1912[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
# 2020
yt_2001[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2001[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2002[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2002[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2003[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2003[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2004[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2004[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2005[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2005[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2006[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2006[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2007[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2007[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2008[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2008[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2009[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2009[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2010[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2010[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2011[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2011[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)
yt_2012[['tpep_pickup_datetime','tpep_dropoff_datetime']] = yt_2012[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime)

# %%
# Extract Hour
# 2019
yt_1901['Hour'] = yt_1901['tpep_pickup_datetime'].dt.hour
yt_1902['Hour'] = yt_1902['tpep_pickup_datetime'].dt.hour
yt_1903['Hour'] = yt_1903['tpep_pickup_datetime'].dt.hour
yt_1904['Hour'] = yt_1904['tpep_pickup_datetime'].dt.hour
yt_1905['Hour'] = yt_1905['tpep_pickup_datetime'].dt.hour
yt_1906['Hour'] = yt_1906['tpep_pickup_datetime'].dt.hour
yt_1907['Hour'] = yt_1907['tpep_pickup_datetime'].dt.hour
yt_1908['Hour'] = yt_1908['tpep_pickup_datetime'].dt.hour
yt_1909['Hour'] = yt_1909['tpep_pickup_datetime'].dt.hour
yt_1910['Hour'] = yt_1910['tpep_pickup_datetime'].dt.hour
yt_1911['Hour'] = yt_1911['tpep_pickup_datetime'].dt.hour
yt_1912['Hour'] = yt_1912['tpep_pickup_datetime'].dt.hour

# 2020
yt_2001['Hour'] = yt_2001['tpep_pickup_datetime'].dt.hour
yt_2002['Hour'] = yt_2002['tpep_pickup_datetime'].dt.hour
yt_2003['Hour'] = yt_2003['tpep_pickup_datetime'].dt.hour
yt_2004['Hour'] = yt_2004['tpep_pickup_datetime'].dt.hour
yt_2005['Hour'] = yt_2005['tpep_pickup_datetime'].dt.hour
yt_2006['Hour'] = yt_2006['tpep_pickup_datetime'].dt.hour
yt_2007['Hour'] = yt_2007['tpep_pickup_datetime'].dt.hour
yt_2008['Hour'] = yt_2008['tpep_pickup_datetime'].dt.hour
yt_2009['Hour'] = yt_2009['tpep_pickup_datetime'].dt.hour
yt_2010['Hour'] = yt_2010['tpep_pickup_datetime'].dt.hour
yt_2011['Hour'] = yt_2011['tpep_pickup_datetime'].dt.hour
yt_2012['Hour'] = yt_2012['tpep_pickup_datetime'].dt.hour

# Extract Day
# 2019
yt_1901['Day'] = yt_1901['tpep_pickup_datetime'].dt.day
yt_1902['Day'] = yt_1902['tpep_pickup_datetime'].dt.day
yt_1903['Day'] = yt_1903['tpep_pickup_datetime'].dt.day
yt_1904['Day'] = yt_1904['tpep_pickup_datetime'].dt.day
yt_1905['Day'] = yt_1905['tpep_pickup_datetime'].dt.day
yt_1906['Day'] = yt_1906['tpep_pickup_datetime'].dt.day
yt_1907['Day'] = yt_1907['tpep_pickup_datetime'].dt.day
yt_1908['Day'] = yt_1908['tpep_pickup_datetime'].dt.day
yt_1909['Day'] = yt_1909['tpep_pickup_datetime'].dt.day
yt_1910['Day'] = yt_1910['tpep_pickup_datetime'].dt.day
yt_1911['Day'] = yt_1911['tpep_pickup_datetime'].dt.day
yt_1912['Day'] = yt_1912['tpep_pickup_datetime'].dt.day

# 2020
yt_2001['Day'] = yt_2001['tpep_pickup_datetime'].dt.day
yt_2002['Day'] = yt_2002['tpep_pickup_datetime'].dt.day
yt_2003['Day'] = yt_2003['tpep_pickup_datetime'].dt.day
yt_2004['Day'] = yt_2004['tpep_pickup_datetime'].dt.day
yt_2005['Day'] = yt_2005['tpep_pickup_datetime'].dt.day
yt_2006['Day'] = yt_2006['tpep_pickup_datetime'].dt.day
yt_2007['Day'] = yt_2007['tpep_pickup_datetime'].dt.day
yt_2008['Day'] = yt_2008['tpep_pickup_datetime'].dt.day
yt_2009['Day'] = yt_2009['tpep_pickup_datetime'].dt.day
yt_2010['Day'] = yt_2010['tpep_pickup_datetime'].dt.day
yt_2011['Day'] = yt_2011['tpep_pickup_datetime'].dt.day
yt_2012['Day'] = yt_2012['tpep_pickup_datetime'].dt.day

# Extract Month and Year
# 2019
yt_1901['Month'] = yt_1901['tpep_pickup_datetime'].dt.month
yt_1901['Year'] = yt_1901['tpep_pickup_datetime'].dt.year
yt_1902['Month'] = yt_1902['tpep_pickup_datetime'].dt.month
yt_1902['Year'] = yt_1902['tpep_pickup_datetime'].dt.year
yt_1903['Month'] = yt_1903['tpep_pickup_datetime'].dt.month
yt_1903['Year'] = yt_1903['tpep_pickup_datetime'].dt.year
yt_1904['Month'] = yt_1904['tpep_pickup_datetime'].dt.month
yt_1904['Year'] = yt_1904['tpep_pickup_datetime'].dt.year
yt_1905['Month'] = yt_1905['tpep_pickup_datetime'].dt.month
yt_1905['Year'] = yt_1905['tpep_pickup_datetime'].dt.year
yt_1906['Month'] = yt_1906['tpep_pickup_datetime'].dt.month
yt_1906['Year'] = yt_1906['tpep_pickup_datetime'].dt.year
yt_1907['Month'] = yt_1907['tpep_pickup_datetime'].dt.month
yt_1907['Year'] = yt_1907['tpep_pickup_datetime'].dt.year
yt_1908['Month'] = yt_1908['tpep_pickup_datetime'].dt.month
yt_1908['Year'] = yt_1908['tpep_pickup_datetime'].dt.year
yt_1909['Month'] = yt_1909['tpep_pickup_datetime'].dt.month
yt_1909['Year'] = yt_1909['tpep_pickup_datetime'].dt.year
yt_1910['Month'] = yt_1910['tpep_pickup_datetime'].dt.month
yt_1910['Year'] = yt_1910['tpep_pickup_datetime'].dt.year
yt_1911['Month'] = yt_1911['tpep_pickup_datetime'].dt.month
yt_1911['Year'] = yt_1911['tpep_pickup_datetime'].dt.year
yt_1912['Month'] = yt_1912['tpep_pickup_datetime'].dt.month
yt_1912['Year'] = yt_1912['tpep_pickup_datetime'].dt.year

# 2020
yt_2001['Month'] = yt_2001['tpep_pickup_datetime'].dt.month
yt_2001['Year'] = yt_2001['tpep_pickup_datetime'].dt.year
yt_2002['Month'] = yt_2002['tpep_pickup_datetime'].dt.month
yt_2002['Year'] = yt_2002['tpep_pickup_datetime'].dt.year
yt_2003['Month'] = yt_2003['tpep_pickup_datetime'].dt.month
yt_2003['Year'] = yt_2003['tpep_pickup_datetime'].dt.year
yt_2004['Month'] = yt_2004['tpep_pickup_datetime'].dt.month
yt_2004['Year'] = yt_2004['tpep_pickup_datetime'].dt.year
yt_2005['Month'] = yt_2005['tpep_pickup_datetime'].dt.month
yt_2005['Year'] = yt_2005['tpep_pickup_datetime'].dt.year
yt_2006['Month'] = yt_2006['tpep_pickup_datetime'].dt.month
yt_2006['Year'] = yt_2006['tpep_pickup_datetime'].dt.year
yt_2007['Month'] = yt_2007['tpep_pickup_datetime'].dt.month
yt_2007['Year'] = yt_2007['tpep_pickup_datetime'].dt.year
yt_2008['Month'] = yt_2008['tpep_pickup_datetime'].dt.month
yt_2008['Year'] = yt_2008['tpep_pickup_datetime'].dt.year
yt_2009['Month'] = yt_2009['tpep_pickup_datetime'].dt.month
yt_2009['Year'] = yt_2009['tpep_pickup_datetime'].dt.year
yt_2010['Month'] = yt_2010['tpep_pickup_datetime'].dt.month
yt_2010['Year'] = yt_2010['tpep_pickup_datetime'].dt.year
yt_2011['Month'] = yt_2011['tpep_pickup_datetime'].dt.month
yt_2011['Year'] = yt_2011['tpep_pickup_datetime'].dt.year
yt_2012['Month'] = yt_2012['tpep_pickup_datetime'].dt.month
yt_2012['Year'] = yt_2012['tpep_pickup_datetime'].dt.year

# %% [markdown]
# For 24 dataset
#
# 1). Convert trip duration in min
#
#  2). Convert mile to km
#
# 3).Caululate Speed _ km per min

# %%
# 2019
yt_1901['trip_duration'] = (yt_1901['tpep_dropoff_datetime'] - yt_1901['tpep_pickup_datetime'])
yt_1901['trip_duration_min'] = yt_1901['trip_duration'].dt.total_seconds()/60
yt_1901['trip_distance_km'] = yt_1901['trip_distance']*1.61
yt_1901['speed'] = yt_1901['trip_distance_km']/yt_1901['trip_duration_min']

yt_1902['trip_duration'] = (yt_1902['tpep_dropoff_datetime'] - yt_1902['tpep_pickup_datetime'])
yt_1902['trip_duration_min'] = yt_1902['trip_duration'].dt.total_seconds()/60
yt_1902['trip_distance_km'] = yt_1902['trip_distance']*1.61
yt_1902['speed'] = yt_1902['trip_distance_km']/yt_1902['trip_duration_min']

yt_1903['trip_duration'] = (yt_1903['tpep_dropoff_datetime'] - yt_1903['tpep_pickup_datetime'])
yt_1903['trip_duration_min'] = yt_1903['trip_duration'].dt.total_seconds()/60
yt_1903['trip_distance_km'] = yt_1903['trip_distance']*1.61
yt_1903['speed'] = yt_1903['trip_distance_km']/yt_1903['trip_duration_min']

yt_1904['trip_duration'] = (yt_1904['tpep_dropoff_datetime'] - yt_1904['tpep_pickup_datetime'])
yt_1904['trip_duration_min'] = yt_1904['trip_duration'].dt.total_seconds()/60
yt_1904['trip_distance_km'] = yt_1904['trip_distance']*1.61
yt_1904['speed'] = yt_1904['trip_distance_km']/yt_1904['trip_duration_min']

yt_1905['trip_duration'] = (yt_1905['tpep_dropoff_datetime'] - yt_1905['tpep_pickup_datetime'])
yt_1905['trip_duration_min'] = yt_1905['trip_duration'].dt.total_seconds()/60
yt_1905['trip_distance_km'] = yt_1905['trip_distance']*1.61
yt_1905['speed'] = yt_1905['trip_distance_km']/yt_1905['trip_duration_min']

yt_1906['trip_duration'] = (yt_1906['tpep_dropoff_datetime'] - yt_1906['tpep_pickup_datetime'])
yt_1906['trip_duration_min'] = yt_1906['trip_duration'].dt.total_seconds()/60
yt_1906['trip_distance_km'] = yt_1906['trip_distance']*1.61
yt_1906['speed'] = yt_1906['trip_distance_km']/yt_1906['trip_duration_min']

yt_1907['trip_duration'] = (yt_1907['tpep_dropoff_datetime'] - yt_1907['tpep_pickup_datetime'])
yt_1907['trip_duration_min'] = yt_1907['trip_duration'].dt.total_seconds()/60
yt_1907['trip_distance_km'] = yt_1907['trip_distance']*1.61
yt_1907['speed'] = yt_1907['trip_distance_km']/yt_1907['trip_duration_min']

yt_1908['trip_duration'] = (yt_1908['tpep_dropoff_datetime'] - yt_1908['tpep_pickup_datetime'])
yt_1908['trip_duration_min'] = yt_1908['trip_duration'].dt.total_seconds()/60
yt_1908['trip_distance_km'] = yt_1908['trip_distance']*1.61
yt_1908['speed'] = yt_1908['trip_distance_km']/yt_1908['trip_duration_min']

yt_1909['trip_duration'] = (yt_1909['tpep_dropoff_datetime'] - yt_1909['tpep_pickup_datetime'])
yt_1909['trip_duration_min'] = yt_1909['trip_duration'].dt.total_seconds()/60
yt_1909['trip_distance_km'] = yt_1909['trip_distance']*1.61
yt_1909['speed'] = yt_1909['trip_distance_km']/yt_1909['trip_duration_min']

yt_1910['trip_duration'] = (yt_1910['tpep_dropoff_datetime'] - yt_1910['tpep_pickup_datetime'])
yt_1910['trip_duration_min'] = yt_1910['trip_duration'].dt.total_seconds()/60
yt_1910['trip_distance_km'] = yt_1910['trip_distance']*1.61
yt_1910['speed'] = yt_1910['trip_distance_km']/yt_1910['trip_duration_min']

yt_1911['trip_duration'] = (yt_1911['tpep_dropoff_datetime'] - yt_1911['tpep_pickup_datetime'])
yt_1911['trip_duration_min'] = yt_1911['trip_duration'].dt.total_seconds()/60
yt_1911['trip_distance_km'] = yt_1911['trip_distance']*1.61
yt_1911['speed'] = yt_1911['trip_distance_km']/yt_1911['trip_duration_min']

yt_1912['trip_duration'] = (yt_1912['tpep_dropoff_datetime'] - yt_1912['tpep_pickup_datetime'])
yt_1912['trip_duration_min'] = yt_1912['trip_duration'].dt.total_seconds()/60
yt_1912['trip_distance_km'] = yt_1912['trip_distance']*1.61
yt_1912['speed'] = yt_1912['trip_distance_km']/yt_1912['trip_duration_min']

#2020
yt_2001['trip_duration'] = (yt_2001['tpep_dropoff_datetime'] - yt_2001['tpep_pickup_datetime'])
yt_2001['trip_duration_min'] = yt_2001['trip_duration'].dt.total_seconds()/60
yt_2001['trip_distance_km'] = yt_2001['trip_distance']*1.61
yt_2001['speed'] = yt_2001['trip_distance_km']/yt_2001['trip_duration_min']

yt_2002['trip_duration'] = (yt_2002['tpep_dropoff_datetime'] - yt_2002['tpep_pickup_datetime'])
yt_2002['trip_duration_min'] = yt_2002['trip_duration'].dt.total_seconds()/60
yt_2002['trip_distance_km'] = yt_2002['trip_distance']*1.61
yt_2002['speed'] = yt_2002['trip_distance_km']/yt_2002['trip_duration_min']

yt_2003['trip_duration'] = (yt_2003['tpep_dropoff_datetime'] - yt_2003['tpep_pickup_datetime'])
yt_2003['trip_duration_min'] = yt_2003['trip_duration'].dt.total_seconds()/60
yt_2003['trip_distance_km'] = yt_2003['trip_distance']*1.61
yt_2003['speed'] = yt_2003['trip_distance_km']/yt_2003['trip_duration_min']

yt_2004['trip_duration'] = (yt_2004['tpep_dropoff_datetime'] - yt_2004['tpep_pickup_datetime'])
yt_2004['trip_duration_min'] = yt_2004['trip_duration'].dt.total_seconds()/60
yt_2004['trip_distance_km'] = yt_2004['trip_distance']*1.61
yt_2004['speed'] = yt_2004['trip_distance_km']/yt_2004['trip_duration_min']

yt_2005['trip_duration'] = (yt_2005['tpep_dropoff_datetime'] - yt_2005['tpep_pickup_datetime'])
yt_2005['trip_duration_min'] = yt_2005['trip_duration'].dt.total_seconds()/60
yt_2005['trip_distance_km'] = yt_2005['trip_distance']*1.61
yt_2005['speed'] = yt_2005['trip_distance_km']/yt_2005['trip_duration_min']

yt_2006['trip_duration'] = (yt_2006['tpep_dropoff_datetime'] - yt_2006['tpep_pickup_datetime'])
yt_2006['trip_duration_min'] = yt_2006['trip_duration'].dt.total_seconds()/60
yt_2006['trip_distance_km'] = yt_2006['trip_distance']*1.61
yt_2006['speed'] = yt_2006['trip_distance_km']/yt_2006['trip_duration_min']

yt_2007['trip_duration'] = (yt_2007['tpep_dropoff_datetime'] - yt_2007['tpep_pickup_datetime'])
yt_2007['trip_duration_min'] = yt_2007['trip_duration'].dt.total_seconds()/60
yt_2007['trip_distance_km'] = yt_2007['trip_distance']*1.61
yt_2007['speed'] = yt_2007['trip_distance_km']/yt_2007['trip_duration_min']

yt_2008['trip_duration'] = (yt_2008['tpep_dropoff_datetime'] - yt_2008['tpep_pickup_datetime'])
yt_2008['trip_duration_min'] = yt_2008['trip_duration'].dt.total_seconds()/60
yt_2008['trip_distance_km'] = yt_2008['trip_distance']*1.61
yt_2008['speed'] = yt_2008['trip_distance_km']/yt_2008['trip_duration_min']

yt_2009['trip_duration'] = (yt_2009['tpep_dropoff_datetime'] - yt_2009['tpep_pickup_datetime'])
yt_2009['trip_duration_min'] = yt_2009['trip_duration'].dt.total_seconds()/60
yt_2009['trip_distance_km'] = yt_2009['trip_distance']*1.61
yt_2009['speed'] = yt_2009['trip_distance_km']/yt_2009['trip_duration_min']

yt_2010['trip_duration'] = (yt_2010['tpep_dropoff_datetime'] - yt_2010['tpep_pickup_datetime'])
yt_2010['trip_duration_min'] = yt_2010['trip_duration'].dt.total_seconds()/60
yt_2010['trip_distance_km'] = yt_2010['trip_distance']*1.61
yt_2010['speed'] = yt_2010['trip_distance_km']/yt_2010['trip_duration_min']

yt_2011['trip_duration'] = (yt_2011['tpep_dropoff_datetime'] - yt_2011['tpep_pickup_datetime'])
yt_2011['trip_duration_min'] = yt_2011['trip_duration'].dt.total_seconds()/60
yt_2011['trip_distance_km'] = yt_2011['trip_distance']*1.61
yt_2011['speed'] = yt_2011['trip_distance_km']/yt_2011['trip_duration_min']

yt_2012['trip_duration'] = (yt_2012['tpep_dropoff_datetime'] - yt_2012['tpep_pickup_datetime'])
yt_2012['trip_duration_min'] = yt_2012['trip_duration'].dt.total_seconds()/60
yt_2012['trip_distance_km'] = yt_2012['trip_distance']*1.61
yt_2012['speed'] = yt_2012['trip_distance_km']/yt_2012['trip_duration_min']

# %%
# Remove Minute and Seconds from Datetime
yt_1901['datetime'] = yt_1901['tpep_pickup_datetime'].dt.floor('H')
yt_1902['datetime'] = yt_1902['tpep_pickup_datetime'].dt.floor('H')
yt_1903['datetime'] = yt_1903['tpep_pickup_datetime'].dt.floor('H')
yt_1904['datetime'] = yt_1904['tpep_pickup_datetime'].dt.floor('H')
yt_1905['datetime'] = yt_1905['tpep_pickup_datetime'].dt.floor('H')
yt_1906['datetime'] = yt_1906['tpep_pickup_datetime'].dt.floor('H')
yt_1907['datetime'] = yt_1907['tpep_pickup_datetime'].dt.floor('H')
yt_1908['datetime'] = yt_1908['tpep_pickup_datetime'].dt.floor('H')
yt_1909['datetime'] = yt_1909['tpep_pickup_datetime'].dt.floor('H')
yt_1910['datetime'] = yt_1910['tpep_pickup_datetime'].dt.floor('H')
yt_1911['datetime'] = yt_1911['tpep_pickup_datetime'].dt.floor('H')
yt_1912['datetime'] = yt_1912['tpep_pickup_datetime'].dt.floor('H')

yt_2001['datetime'] = yt_2001['tpep_pickup_datetime'].dt.floor('H')
yt_2002['datetime'] = yt_2002['tpep_pickup_datetime'].dt.floor('H')
yt_2003['datetime'] = yt_2003['tpep_pickup_datetime'].dt.floor('H')
yt_2004['datetime'] = yt_2004['tpep_pickup_datetime'].dt.floor('H')
yt_2005['datetime'] = yt_2005['tpep_pickup_datetime'].dt.floor('H')
yt_2006['datetime'] = yt_2006['tpep_pickup_datetime'].dt.floor('H')
yt_2007['datetime'] = yt_2007['tpep_pickup_datetime'].dt.floor('H')
yt_2008['datetime'] = yt_2008['tpep_pickup_datetime'].dt.floor('H')
yt_2009['datetime'] = yt_2009['tpep_pickup_datetime'].dt.floor('H')
yt_2010['datetime'] = yt_2010['tpep_pickup_datetime'].dt.floor('H')
yt_2011['datetime'] = yt_2011['tpep_pickup_datetime'].dt.floor('H')
yt_2012['datetime'] = yt_2012['tpep_pickup_datetime'].dt.floor('H')

# %% [markdown]
# Data Cleansing

# %%
# 2019
validind_1901 =  (yt_1901.trip_duration_min > 0) & (yt_1901.trip_distance > 0) & (yt_1901.fare_amount > 0)& (yt_1901.speed < 10)&(yt_1901.Month == 1)&(yt_1901.Year == 2019)
yt_1901 = yt_1901[validind_1901]

validind_1902 =  (yt_1902.trip_duration_min > 0) & (yt_1902.trip_distance > 0) & (yt_1902.fare_amount > 0)& (yt_1902.speed < 10)&(yt_1902.Month == 2)&(yt_1902.Year == 2019)
yt_1902 = yt_1902[validind_1902]

validind_1903 =  (yt_1903.trip_duration_min > 0) & (yt_1903.trip_distance > 0) & (yt_1903.fare_amount > 0)& (yt_1903.speed < 10)&(yt_1903.Month == 3)&(yt_1903.Year == 2019)
yt_1903 = yt_1903[validind_1903]

validind_1904 =  (yt_1904.trip_duration_min > 0) & (yt_1904.trip_distance > 0) & (yt_1904.fare_amount > 0)& (yt_1904.speed < 10)&(yt_1904.Month == 4)&(yt_1904.Year == 2019)
yt_1904 = yt_1904[validind_1904]

validind_1905 =  (yt_1905.trip_duration_min > 0) & (yt_1905.trip_distance > 0) & (yt_1905.fare_amount > 0)& (yt_1905.speed < 10)&(yt_1905.Month == 5)&(yt_1905.Year == 2019)
yt_1905 = yt_1905[validind_1905]

validind_1906 =  (yt_1906.trip_duration_min > 0) & (yt_1906.trip_distance > 0) & (yt_1906.fare_amount > 0)& (yt_1906.speed < 10)&(yt_1906.Month == 6)&(yt_1906.Year == 2019)
yt_1906 = yt_1906[validind_1906]

validind_1907 =  (yt_1907.trip_duration_min > 0) & (yt_1907.trip_distance > 0) & (yt_1907.fare_amount > 0)& (yt_1907.speed < 10)&(yt_1907.Month == 7)&(yt_1907.Year == 2019)
yt_1907 = yt_1907[validind_1907]

validind_1908 =  (yt_1908.trip_duration_min > 0) & (yt_1908.trip_distance > 0) & (yt_1908.fare_amount > 0)& (yt_1908.speed < 10)&(yt_1908.Month == 8)&(yt_1908.Year == 2019)
yt_1908 = yt_1908[validind_1908]

validind_1909 =  (yt_1909.trip_duration_min > 0) & (yt_1909.trip_distance > 0) & (yt_1909.fare_amount > 0)& (yt_1909.speed < 10)&(yt_1909.Month == 9)&(yt_1909.Year == 2019)
yt_1909 = yt_1909[validind_1909]

validind_1910 =  (yt_1910.trip_duration_min > 0) & (yt_1910.trip_distance > 0) & (yt_1910.fare_amount > 0)& (yt_1910.speed < 10)&(yt_1910.Month == 10)&(yt_1910.Year == 2019)
yt_1910 = yt_1910[validind_1910]

validind_1911 =  (yt_1911.trip_duration_min > 0) & (yt_1911.trip_distance > 0) & (yt_1911.fare_amount > 0)& (yt_1911.speed < 10)&(yt_1911.Month == 11)&(yt_1911.Year == 2019)
yt_1911 = yt_1911[validind_1911]

validind_1912 =  (yt_1912.trip_duration_min > 0) & (yt_1912.trip_distance > 0) & (yt_1912.fare_amount > 0)& (yt_1912.speed < 10)&(yt_1912.Month == 12)&(yt_1912.Year == 2019)
yt_1912 = yt_1912[validind_1912]

# 2020
validind_2001 =  (yt_2001.trip_duration_min > 0) & (yt_2001.trip_distance > 0) & (yt_2001.fare_amount > 0)& (yt_2001.speed < 10)&(yt_2001.Month == 1)&(yt_2001.Year == 2020)
yt_2001 = yt_2001[validind_2001]

validind_2002 =  (yt_2002.trip_duration_min > 0) & (yt_2002.trip_distance > 0) & (yt_2002.fare_amount > 0)& (yt_2002.speed < 10)&(yt_2002.Month == 2)&(yt_2002.Year == 2020)
yt_2002 = yt_2002[validind_2002]

validind_2003 =  (yt_2003.trip_duration_min > 0) & (yt_2003.trip_distance > 0) & (yt_2003.fare_amount > 0)& (yt_2003.speed < 10)&(yt_2003.Month == 3)&(yt_2003.Year == 2020)
yt_2003 = yt_2003[validind_2003]

validind_2004 =  (yt_2004.trip_duration_min > 0) & (yt_2004.trip_distance > 0) & (yt_2004.fare_amount > 0)& (yt_2004.speed < 10)&(yt_2004.Month == 4)&(yt_2004.Year == 2020)
yt_2004 = yt_2004[validind_2004]

validind_2005 =  (yt_2005.trip_duration_min > 0) & (yt_2005.trip_distance > 0) & (yt_2005.fare_amount > 0)& (yt_2005.speed < 10)&(yt_2005.Month == 5)&(yt_2005.Year == 2020)
yt_2005 = yt_2005[validind_2005]

validind_2006 =  (yt_2006.trip_duration_min > 0) & (yt_2006.trip_distance > 0) & (yt_2006.fare_amount > 0)& (yt_2006.speed < 10)&(yt_2006.Month == 6)&(yt_2006.Year == 2020)
yt_2006 = yt_2006[validind_2006]

validind_2007 =  (yt_2007.trip_duration_min > 0) & (yt_2007.trip_distance > 0) & (yt_2007.fare_amount > 0)& (yt_2007.speed < 10)&(yt_2007.Month == 7)&(yt_2007.Year == 2020)
yt_2007 = yt_2007[validind_2007]

validind_2008 =  (yt_2008.trip_duration_min > 0) & (yt_2008.trip_distance > 0) & (yt_2008.fare_amount > 0)& (yt_2008.speed < 10)&(yt_2008.Month == 8)&(yt_2008.Year == 2020)
yt_2008 = yt_2008[validind_2008]

validind_2009 =  (yt_2009.trip_duration_min > 0) & (yt_2009.trip_distance > 0) & (yt_2009.fare_amount > 0)& (yt_2009.speed < 10)&(yt_2009.Month == 9)&(yt_2009.Year == 2020)
yt_2009 = yt_2009[validind_2009]

validind_2010 =  (yt_2010.trip_duration_min > 0) & (yt_2010.trip_distance > 0) & (yt_2010.fare_amount > 0)& (yt_2010.speed < 10)&(yt_2010.Month == 10)&(yt_2010.Year == 2020)
yt_2010 = yt_2010[validind_2010]

validind_2011 =  (yt_2011.trip_duration_min > 0) & (yt_2011.trip_distance > 0) & (yt_2011.fare_amount > 0)& (yt_2011.speed < 10)&(yt_2011.Month == 7)&(yt_2011.Year == 2020)
yt_2011 = yt_2011[validind_2011]

validind_2012 =  (yt_2012.trip_duration_min > 0) & (yt_2012.trip_distance > 0) & (yt_2012.fare_amount > 0)& (yt_2012.speed < 10)&(yt_2012.Month == 12)&(yt_2012.Year == 2020)
yt_2012 = yt_2012[validind_2012]

# %% [markdown]
# ### Overall with Datetime_Hourly Avg

# %%
# 2019
overall_1901 = yt_1901.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1902 = yt_1902.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1903 = yt_1903.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1904 = yt_1904.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1905 = yt_1905.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1906 = yt_1906.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1907 = yt_1907.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1908 = yt_1908.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1909 = yt_1909.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1910 = yt_1910.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1911 = yt_1911.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_1912 = yt_1912.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
# 2020
overall_2001 = yt_2001.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2002 = yt_2002.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2003 = yt_2003.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2004 = yt_2004.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2005 = yt_2005.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2006 = yt_2006.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2007 = yt_2007.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2008 = yt_2008.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2009 = yt_2009.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2010 = yt_2010.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2011 = yt_2011.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
overall_2012 = yt_2012.groupby(['datetime']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()

# %%
frames_overall = [overall_1901, overall_1902,overall_1903,overall_1904,overall_1905,overall_1906,\
                 overall_1907,overall_1908,overall_1909,overall_1910,overall_1911,overall_1912,\
                 overall_2001, overall_2002,overall_2003,overall_2004,overall_2005,overall_2006,\
                 overall_2007,overall_2008,overall_2009,overall_2010,overall_2011,overall_2012]
Overall = pd.concat(frames_overall )
Overall
# Out:
#                datetime  trip_distance_km  number_of_trips  trip_duration_min
# 0   2019-01-01 00:00:00          4.720726            13315          19.692901
# 1   2019-01-01 01:00:00          4.974352            15300          19.125712
# 2   2019-01-01 02:00:00          5.168780            13066          18.587717
# 3   2019-01-01 03:00:00          5.320578            10330          20.128028
# 4   2019-01-01 04:00:00          6.015227             6758          21.093351
# ..                  ...               ...              ...                ...
# 739 2020-12-31 19:00:00          4.934031             2379          12.541264
# 740 2020-12-31 20:00:00          5.045343             1793          11.819716
# 741 2020-12-31 21:00:00          5.251402             1425          16.964433
# 742 2020-12-31 22:00:00          5.265098             1377          19.316751
# 743 2020-12-31 23:00:00          5.812255              932          17.337482
#
# [16822 rows x 4 columns]

# %%
# Save file
# Overall.to_csv (r'C:\Users\Jin\2019_2020_Yellow_Taxi_Datetime.csv',index=False)

# %%
Time = Overall['datetime'].values

# %%
plt.figure(figsize = (50,10))
plt.title('Yellow Taxicab_Hourly')
plt.xlabel('time')
plt.ylabel('count')
yellow_data_line = plt.plot(Overall.datetime,Overall.number_of_trips, label = 'Yellow Taxicab', color = 'yellow')
yellow_mean_line = plt.plot(Overall.datetime,Overall.number_of_trips.rolling(window = 30).mean(), label='Yellow Mean', linestyle='--')
plt.show()

# %% [markdown]
# ### Overall with Datetime_ Daily Avg

# %%
Overall_Daily = pd.concat(frames_overall)
# Remove Hour from Datetime
Overall_Daily['datetime'] = Overall_Hourly['datetime'].dt.floor('D')

Overall_Daily = Overall_Daily.groupby(['datetime']).agg({'trip_distance_km':'mean','number_of_trips':'sum','trip_duration_min':'mean'}).\
        rename(columns={'number_of_trips':'Overall_Daily_Trips'}).reset_index()

# %%
plt.style.use('ggplot')
plt.figure(figsize = (20,5))
plt.title('Yellow Taxicab_Daily Trips')
plt.xlabel('time')
plt.ylabel('count')
yellow_data_line = plt.plot(Overall_Daily.datetime,Overall_Daily.Overall_Daily_Trips, label = 'Yellow Taxicab', color = 'green',alpha=0.5)
yellow_mean_line = plt.plot(Overall_Daily.datetime,Overall_Daily.Overall_Daily_Trips.rolling(window = 30).mean(), label='Yellow Mean', linestyle='--')
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Yellow Taxicab_Daily Distance')
plt.xlabel('time')
plt.ylabel('count')
yellow_data_line = plt.plot(Overall_Daily.datetime,Overall_Daily.trip_distance_km, label = 'Yellow Taxicab', color = 'green',alpha=0.5)
yellow_mean_line = plt.plot(Overall_Daily.datetime,Overall_Daily.trip_distance_km.rolling(window = 30).mean(), label='Yellow Mean', linestyle='--')
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Yellow Taxicab_Daily Trip Duration')
plt.xlabel('time')
plt.ylabel('count')
yellow_data_line = plt.plot(Overall_Daily.datetime,Overall_Daily.trip_duration_min, label = 'Yellow Taxicab', color = 'green',alpha=0.5)
yellow_mean_line = plt.plot(Overall_Daily.datetime,Overall_Daily.trip_duration_min.rolling(window = 30).mean(), label='Yellow Mean', linestyle='--')
plt.show()

# %% [markdown]
# ### Overall in 2019 and 2020

# %%
# Overall 2019

frames_overall_19 = [overall_1901, overall_1902,overall_1903,overall_1904,overall_1905,overall_1906,\
                 overall_1907,overall_1908,overall_1909,overall_1910,overall_1911,overall_1912]
Overall_19 = pd.concat(frames_overall_19 )

# Overall 2020
frames_overall_20 = [overall_2001, overall_2002,overall_2003,overall_2004,overall_2005,overall_2006,\
                 overall_2007,overall_2008,overall_2009,overall_2010,overall_2011,overall_2012]
Overall_20 = pd.concat(frames_overall_20)

# %%
Overall_19['Month'] = Overall_19['datetime'].dt.month
Overall_19['Day'] = Overall_19['datetime'].dt.day
Overall_19['Hour'] = Overall_19['datetime'].dt.hour

Overall_20['Month'] = Overall_20['datetime'].dt.month
Overall_20['Day'] = Overall_20['datetime'].dt.day
Overall_20['Hour'] = Overall_20['datetime'].dt.hour

# %% [markdown]
# ### Overall with Year Month Day Hour

# %%
# 2019
oa_ymdh_1901 = yt_1901.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1902 = yt_1902.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1903 = yt_1903.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1904 = yt_1904.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1905 = yt_1905.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1906 = yt_1906.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1907 = yt_1907.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1908 = yt_1908.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1909 = yt_1909.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1910 = yt_1910.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1911 = yt_1911.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_1912 = yt_1912.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()

# 2020 
oa_ymdh_2001 = yt_2001.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2002 = yt_2002.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2003 = yt_2003.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2004 = yt_2004.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2005 = yt_2005.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2006 = yt_2006.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2007 = yt_2007.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2008 = yt_2008.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2009 = yt_2009.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2010 = yt_2010.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2011 = yt_2011.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()
oa_ymdh_2012 = yt_2012.groupby(['Year','Month','Day','Hour']).agg({'trip_distance_km':'mean','tpep_dropoff_datetime':'count','trip_duration_min':'mean'}).\
        rename(columns={'tpep_dropoff_datetime':'number_of_trips'}).reset_index()

# %%
frames_oa_ymdh = [oa_ymdh_1901, oa_ymdh_1902,oa_ymdh_1903,oa_ymdh_1904,oa_ymdh_1905,oa_ymdh_1906,\
                 oa_ymdh_1907,oa_ymdh_1908,oa_ymdh_1909,oa_ymdh_1910,oa_ymdh_1911,oa_ymdh_1912,\
                 oa_ymdh_2001, oa_ymdh_2002,oa_ymdh_2003,oa_ymdh_2004,oa_ymdh_2005,oa_ymdh_2006,\
                 oa_ymdh_2007,oa_ymdh_2008,oa_ymdh_2009,oa_ymdh_2010,oa_ymdh_2011,oa_ymdh_2012]
oa_ymdh = pd.concat(frames_oa_ymdh )
oa_ymdh
# Out:
#      Year  Month  Day  Hour  trip_distance_km  number_of_trips  \
# 0    2019      1    1     0          4.720726            13315
# 1    2019      1    1     1          4.974352            15300
# 2    2019      1    1     2          5.168780            13066
# 3    2019      1    1     3          5.320578            10330
# 4    2019      1    1     4          6.015227             6758
# ..    ...    ...  ...   ...               ...              ...
# 739  2020     12   31    19          4.934031             2379
# 740  2020     12   31    20          5.045343             1793
# 741  2020     12   31    21          5.251402             1425
# 742  2020     12   31    22          5.265098             1377
# 743  2020     12   31    23          5.812255              932
#
#      trip_duration_min
# 0            19.692901
# 1            19.125712
# 2            18.587717
# 3            20.128028
# 4            21.093351
# ..                 ...
# 739          12.541264
# ...

# %%
# Save file
oa_ymdh.to_csv (r'C:\Users\Jin\2019_2020_Yellow_Taxi_YMDH.csv',index=False)

# %% [markdown]
# ### 2019_ January

# %%
# Hourly trip count each day
count_1901 = yt_1901[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1901 = yt_1901[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1901 = yt_1901[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1901 = yt_1901[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_February

# %%
# Hourly trip count each day
count_1902 = yt_1902[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1902 = yt_1902[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1902 = yt_1902[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1902 = yt_1902[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_ March

# %%
# Hourly trip count each day
count_1903 = yt_1903[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1903 = yt_1903[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1903 = yt_1903[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1903 = yt_1903[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_April

# %%
# Hourly trip count each day
count_1904 = yt_1904[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1904 = yt_1904[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1904 = yt_1904[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1904 = yt_1904[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_May

# %%
# Hourly trip count each day
count_1905 = yt_1905[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1905 = yt_1905[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1905 = yt_1905[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1905 = yt_1905[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_ June

# %%
# Hourly trip count each day
count_1906 = yt_1906[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1906 = yt_1906[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1906 = yt_1906[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1906 = yt_1906[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_July

# %%
# Hourly trip count each day
count_1907 = yt_1907[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1907 = yt_1907[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1907 = yt_1907[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1907 = yt_1907[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_August

# %%
# Hourly trip count each day
count_1908 = yt_1908[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1908 = yt_1908[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1908 = yt_1908[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1908 = yt_1908[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_September

# %%
# Hourly trip count each day
count_1909 = yt_1909[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1909 = yt_1909[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1909 = yt_1909[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1909 = yt_1909[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_October

# %%
# Hourly trip count each day
count_1910 = yt_1910[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1910 = yt_1910[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1910 = yt_1910[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1910 = yt_1910[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_November

# %%
# Hourly trip count each day
count_1911 = yt_1911[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1911 = yt_1911[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1911 = yt_1911[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1911 = yt_1911[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2019_December

# %%
# Hourly trip count each day
count_1912 = yt_1912[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_1912 = yt_1912[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_1912 = yt_1912[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_1912 = yt_1912[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_January

# %%
# Hourly trip count each day
count_2001 = yt_2001[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2001 = yt_2001[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2001 = yt_2001[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2001 = yt_2001[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_February

# %%
# Hourly trip count each day
count_2002 = yt_2002[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2002 = yt_2002[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2002 = yt_2002[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2002 = yt_2002[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_March

# %%
# Hourly trip count each day
count_2003 = yt_2003[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2003 = yt_2003[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2003 = yt_2003[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2003 = yt_2003[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_April

# %%
# Hourly trip count each day
count_2004 = yt_2004[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2004 = yt_2004[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2004 = yt_2004[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2004 = yt_2004[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_May

# %%
# Hourly trip count each day
count_2005 = yt_2005[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2005 = yt_2005[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2005 = yt_2005[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2005 = yt_2005[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_June

# %%
# Hourly trip count each day
count_2006 = yt_2006[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2006 = yt_2006[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2006 = yt_2006[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2006 = yt_2006[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_July

# %%
# Hourly trip count each day
count_2007 = yt_2007[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2007 = yt_2007[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2007 = yt_2007[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2007 = yt_2007[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_August

# %%
# Hourly trip count each day
count_2008 = yt_2008[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2008 = yt_2008[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2008 = yt_2008[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2008 = yt_2008[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_September

# %%
# Hourly trip count each day
count_2009 = yt_2009[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2009 = yt_2009[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2009 = yt_2009[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2009 = yt_2009[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_October

# %%
# Hourly trip count each day
count_2010 = yt_2010[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2010 = yt_2010[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2010 = yt_2010[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2010 = yt_2010[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_November

# %%
# Hourly trip count each day
count_2011 = yt_2011[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2011 = yt_2011[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2011 = yt_2011[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2011 = yt_2011[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### 2020_December

# %%
# Hourly trip count each day
count_2012 = yt_2012[['Year','Month','Day','Hour','tpep_dropoff_datetime']].groupby(['Year','Month','Day','Hour']).count()

# Hourly average distance each day
avgdistance_2012 = yt_2012[['Year','Month','Day','Hour','trip_distance']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average trip duration in min each day
avgtime_2012 = yt_2012[['Year','Month','Day','Hour','trip_duration_min']].groupby(['Year','Month','Day','Hour']).mean()

# Hourly average speed (km per min) each day
avgspeed_2012 = yt_2012[['Year','Month','Day','Hour','speed']].groupby(['Year','Month','Day','Hour']).mean()

# %% [markdown]
# ### Overall

# %% [markdown]
# ### Overall Hourly Count

# %%
# Hourly trip count each day
# 2019
hourlycount_1901= yt_1901[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1902= yt_1902[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1903= yt_1903[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1904= yt_1904[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1905= yt_1905[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1906= yt_1906[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1907= yt_1907[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1908= yt_1908[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1909= yt_1909[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1910= yt_1910[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1911= yt_1911[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_1912= yt_1912[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
#2000
hourlycount_2001= yt_2001[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2002= yt_2002[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2003= yt_2003[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2004= yt_2004[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2005= yt_2005[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2006= yt_2006[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2007= yt_2007[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2008= yt_2008[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2009= yt_2009[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2010= yt_2010[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2011= yt_2011[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()
hourlycount_2012= yt_2012[['datetime','tpep_dropoff_datetime']].groupby(['datetime']).count()

# %%
frames = [hourlycount_1901, hourlycount_1902,hourlycount_1903,hourlycount_1904,hourlycount_1905,hourlycount_1906,\
          hourlycount_1907,hourlycount_1908,hourlycount_1909,hourlycount_1910,hourlycount_1911,hourlycount_1912,\
          hourlycount_2001, hourlycount_2002,hourlycount_2003,hourlycount_2004,hourlycount_2005,hourlycount_2006,\
          hourlycount_2007,hourlycount_2008,hourlycount_2009,hourlycount_2010,hourlycount_2011,hourlycount_2012]

# %%
pandas.set_option('display.max_rows', None)

# %%
Overall_count = pd.concat(frames)
Overall_count
# Out:
#                      tpep_dropoff_datetime
# datetime
# 2019-01-01 00:00:00                  13315
# 2019-01-01 01:00:00                  15300
# 2019-01-01 02:00:00                  13066
# 2019-01-01 03:00:00                  10330
# 2019-01-01 04:00:00                   6758
# ...                                    ...
# 2020-12-31 19:00:00                   2379
# 2020-12-31 20:00:00                   1793
# 2020-12-31 21:00:00                   1425
# 2020-12-31 22:00:00                   1377
# 2020-12-31 23:00:00                    932
#
# [16822 rows x 1 columns]

# %%
count_2012
